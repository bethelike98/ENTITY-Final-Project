# %% [markdown]
# # Background
# The dataset

# %% [markdown]
# ### Importing Packages

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import RegexpTokenizer
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Reading Dataset

# %%
train = pd.read_csv("Data/train.csv")
train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Dropping ID column

# %%
train = train[['text','selected_text', 'sentiment']]

# %%
train.head()
# Out:
#                                                 text  \
# 0                I`d have responded, if I were going
# 1      Sooo SAD I will miss you here in San Diego!!!
# 2                          my boss is bullying me...
# 3                     what interview! leave me alone
# 4   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %% [markdown]
# ### Tokenizing the Data & Remove Capitalization

# %%
train['text'] = train.text.astype(str).str.lower()
tokenizer = RegexpTokenizer('\w+')
train['tokens'] = train['text'].apply(tokenizer.tokenize)
train.head()
# Out:
#                                                 text  \
# 0                i`d have responded, if i were going
# 1      sooo sad i will miss you here in san diego!!!
# 2                          my boss is bullying me...
# 3                     what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                                               tokens
# 0        [i, d, have, responded, if, i, were, going]
# 1  [sooo, sad, i, will, miss, you, here, in, san,...
# 2                       [my, boss, is, bullying, me]
# 3                [what, interview, leave, me, alone]
# 4  [sons, of, why, couldn, t, they, put, them, on...

# %% [markdown]
# ### Removing Stopwords from Tokens List

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
df['D'] = df.C.isin(firsts).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24960/2322614118.py in <module>
# ----> 1 df['D'] = df.C.isin(firsts).astype(int)
#
# NameError: name 'df' is not defined

# %%
train['sample']=train.tokens.isin(stopwords).any()

# %%
train.head()
# Out:
#                                                 text  \
# 0                i`d have responded, if i were going
# 1      sooo sad i will miss you here in san diego!!!
# 2                          my boss is bullying me...
# 3                     what interview! leave me alone
# 4   sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                                               tokens  sample
# 0        [i, d, have, responded, if, i, were, going]   False
# 1  [sooo, sad, i, will, miss, you, here, in, san,...   False
# 2                       [my, boss, is, bullying, me]   False
# 3                [what, interview, leave, me, alone]   False
# 4  [sons, of, why, couldn, t, they, put, them, on...   False

# %% [markdown]
# ## Sentiment DataFrames

# %% [markdown]
# Here, we will break the larger dataframe into smaller dataframes of neutral, negative, and positive sentiments. We will also produce word clouds to see which words influence sentiment classification.

# %% [markdown]
# ### Neutral Sentiment

# %%
neutral_tokens = []
neutral = train[train['sentiment']=='neutral']

# %%
neutral.head()
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 5   http://www.dothebouncy.com/smf - some shameles...
# 7                                          soooo high
# 8                                         both of you
# 10   as much as i love to be hopeful, i reckon the...
#
#                                         selected_text sentiment  \
# 0                 I`d have responded, if I were going   neutral
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 7                                          Soooo high   neutral
# 8                                         Both of you   neutral
# 10  as much as i love to be hopeful, i reckon the ...   neutral
#
#                                                tokens  sample
# 0         [i, d, have, responded, if, i, were, going]   False
# 5   [http, www, dothebouncy, com, smf, some, shame...   False
# 7                                       [soooo, high]   False
# 8                                     [both, of, you]   False
# 10  [as, much, as, i, love, to, be, hopeful, i, re...   False

# %%
for item in neutral['tokens']:
    for token in item:
        neutral_tokens.append(token)

# %%
neutral.head()
# Out:
#                                                  text  \
# 0                 i`d have responded, if i were going
# 5   http://www.dothebouncy.com/smf - some shameles...
# 7                                          soooo high
# 8                                         both of you
# 10   as much as i love to be hopeful, i reckon the...
#
#                                         selected_text sentiment  \
# 0                 I`d have responded, if I were going   neutral
# 5   http://www.dothebouncy.com/smf - some shameles...   neutral
# 7                                          Soooo high   neutral
# 8                                         Both of you   neutral
# 10  as much as i love to be hopeful, i reckon the ...   neutral
#
#                                                tokens  sample
# 0         [i, d, have, responded, if, i, were, going]   False
# 5   [http, www, dothebouncy, com, smf, some, shame...   False
# 7                                       [soooo, high]   False
# 8                                     [both, of, you]   False
# 10  [as, much, as, i, love, to, be, hopeful, i, re...   False

# %%
! pip3 install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.1 in c:\python3\lib\site-packages (from wordcloud) (1.22.0)
# Requirement already satisfied: pillow in c:\users\valmh\appdata\roaming\python\python39\site-packages (from wordcloud) (9.0.0)
# WARNING: You are using pip version 22.0.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Python3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in c:\users\valmh\appdata\roaming\python\python39\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\valmh\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\python3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\valmh\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\valmh\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (4.29.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python3\lib\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\python3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Using legacy 'setup.py install' for wordcloud, since package 'wheel' is not installed.
# Installing collected packages: wordcloud
#   Running setup.py install for wordcloud: started
#   Running setup.py install for wordcloud: finished with status 'done'
# Successfully installed wordcloud-1.8.1

# %%
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import numpy as np

# %%
def show_wordcloud(neutral):
    wordcloud = WordCloud(
        background_color='white',
        max_words=200,
        max_font_size=30,
        scale=3,
        colormap= 'inferno',
        random_state=1)
    
    wordcloud=wordcloud.generate(str(neutral))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(neutral)

# %% [markdown]
# ### Positive Sentiment

# %%
pos_tokens = []
pos = train[train['sentiment']=='positive']

# %%
pos.head()
# Out:
#                                                  text  \
# 6   2am feedings for the baby are fun when he is a...
# 9    journey!? wow... u just became cooler.  hehe....
# 11  i really really like the song love story by ta...
# 21  playing ghost online is really interesting. th...
# 25  the free fillin` app on my ipod is fun, im add...
#
#                                         selected_text sentiment  \
# 6                                                 fun  positive
# 9                        Wow... u just became cooler.  positive
# 11                                               like  positive
# 21                                       interesting.  positive
# 25  the free fillin` app on my ipod is fun, im add...  positive
#
#                                                tokens  sample
# 6   [2am, feedings, for, the, baby, are, fun, when...   False
# 9   [journey, wow, u, just, became, cooler, hehe, ...   False
# 11  [i, really, really, like, the, song, love, sto...   False
# 21  [playing, ghost, online, is, really, interesti...   False
# 25  [the, free, fillin, app, on, my, ipod, is, fun...   False

# %%
for item in pos['tokens']:
    for token in item:
        pos_tokens.append(token)

# %%
def show_wordcloud(pos):
    wordcloud = WordCloud(
        background_color='white',
        max_words=200,
        max_font_size=30,
        scale=3,
        colormap= 'viridis',
        random_state=1)
    
    wordcloud=wordcloud.generate(str(pos))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(pos)

# %% [markdown]
# ### Negative Sentiment

# %%
neg_tokens = []
neg = train[train['sentiment']=='negative']

# %%
neg.head()
# Out:
#                                                  text   selected_text  \
# 1       sooo sad i will miss you here in san diego!!!        Sooo SAD
# 2                           my boss is bullying me...     bullying me
# 3                      what interview! leave me alone  leave me alone
# 4    sons of ****, why couldn`t they put them on t...   Sons of ****,
# 12       my sharpie is running dangerously low on ink     DANGERously
#
#    sentiment                                             tokens  sample
# 1   negative  [sooo, sad, i, will, miss, you, here, in, san,...   False
# 2   negative                       [my, boss, is, bullying, me]   False
# 3   negative                [what, interview, leave, me, alone]   False
# 4   negative  [sons, of, why, couldn, t, they, put, them, on...   False
# 12  negative  [my, sharpie, is, running, dangerously, low, o...   False

# %%
for item in neg['tokens']:
    for token in item:
        neg_tokens.append(token)

# %%
def show_wordcloud(neg):
    wordcloud = WordCloud(
        background_color='white',
        max_words=200,
        max_font_size=30,
        scale=3,
        colormap= 'twilight',
        random_state=1)
    
    wordcloud=wordcloud.generate(str(neg))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(neg)
